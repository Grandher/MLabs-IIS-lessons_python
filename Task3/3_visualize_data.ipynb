# %% [markdown]
# # Визуализация данных в Python

# %% [markdown]
# ## Обзор библиотек

# %% [markdown]
# 1. Matplotlib - базовая графика
# 2. Seaborn - углубленная базовая графика
# 3. Plotly - динамические графики

# %% [markdown]
# | Matplotlib | Seaborn |
# | ----------- | ----------- |
# | Используется для базового построения графиков, таких как линейные диаграммы, гистограммы и т. д.    | Используется для визуализации статистики и может выполнять сложные визуализации с меньшим количеством команд.   |
# |  Продуктивно работает с массивами данных и фреймами.  | Seaborn значительно более организован и функционален, чем Matplotlib, и рассматривает весь набор данных как единую единицу.   |
# | Matplotlib более настраиваемый и хорошо сочетается с Pandas и Numpy для анализа исследуемых данных.   | Seaborn имеет больше встроенных тем и в основном используется для статистического анализа.  |

# %% [markdown]
# ## Линейные графики

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Сгенерируем простой набор данных.

# %%
y = [1, 2, 3, 3.5, 3.7, 4, 4.1]

# %% [markdown]
# Визуализируем с помощью функции **plot**.

# %%
plt.plot(y)
plt.show()

# %% [markdown]
# Добавим ось ОХ.

# %%
x = [2017, 2018, 2019, 2020, 2021, 2022, 2023]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# Добавляем подписи осей.

# %%
plt.plot(x,y)
plt.xlabel('Год')
plt.ylabel('Значения показателя')
plt.show()

# %% [markdown]
# Добавляем второй набор данных и отрисовываем оба ряда на одном графике.

# %%
#y = [1, 2, 3, 3.5, 3.7, 4, 4.1]
y2 = [6.8, 6.7, 6.5, 5, 5.1, 3.0, 2]
#x = [2017, 2018, 2019, 2020, 2021, 2022, 2023]
plt.plot(x,y)
plt.plot(x,y2)
plt.xlabel('Год')
plt.ylabel('Показатели')
plt.show()

# %% [markdown]
# Добавляем легенду.

# %%
plt.plot(x,y)
plt.plot(x,y2)
plt.xlabel('Год')
plt.ylabel('Показатели')
plt.title('Динамика показателя')
plt.legend(['y', 'y2'])
plt.show()

# %% [markdown]
# Добавляем маркеры для выделения каждого наблюдения.

# %%
plt.plot(x,y, marker = 'o')
plt.plot(x,y2, marker = 'x')
plt.xlabel('Год')
plt.ylabel('Показатели')
plt.title('Динамика показателя')
plt.legend(['y', 'y2'])
plt.show()

# %% [markdown]
# Построим все то же самое с помощью библиотеки **Seaborn**.

# %%
sns.set_style("whitegrid") #darkgrid

plt.plot(x,y, marker = 'o')
plt.plot(x,y2, marker = 'x')
plt.xlabel('Год')
plt.ylabel('Показатели')
plt.title('Динамика показателя')
plt.legend(['y', 'y2'])
plt.show()

# %% [markdown]
# ## Barplot или столбчатые графики

# %%
plt.bar(x,y)
plt.xlabel('Год')
plt.ylabel('Показатели')
plt.title('Динамика показателя')
plt.show()

# %%
plt.bar(x,y)
plt.bar(x,y2, bottom = y)
plt.show()

# %% [markdown]
# ## График-пирог

# %%
x_labels = ['2017', '2018', '2019', '2020', '2021', '2022', '2023']
plt.pie(y, labels = x_labels)
plt.show()

# %% [markdown]
# ## Гистограммы

# %%
iris = sns.load_dataset("iris")
plt.hist(iris.sepal_length)
plt.show()

# %% [markdown]
# Можем задать количество блоков с помощью параметра **bins**.

# %%
plt.hist(iris.sepal_length, bins = 100)
plt.show()

# %% [markdown]
# Регулируем прозрачность гистограммы с помощью параметра **alpha**. Можем построить гистограммы для нескольких наборов данных на одном графике.

# %%
plt.hist(iris.sepal_length, alpha = 0.4)
plt.hist(iris.petal_length, alpha = 0.4)
plt.show()

# %% [markdown]
# Параметр **stacked** для совместной отрисовки данных.

# %%
plt.hist([iris.sepal_length,iris.petal_length], stacked = True)
plt.show()

# %% [markdown]
# ## Точечные графики или scatteplot

# %%
ax = sns.scatterplot(x='petal_length', y='sepal_length', data=iris)
plt.show()
# Out:
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
ax = sns.scatterplot(x="petal_length", y="sepal_length", data=iris, hue = 'species')
plt.show()
# Out:
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ## Тепловые карты

# %%
#flights = sns.load_dataset("flights").pivot("month", "year", "passengers")
flights = sns.load_dataset("flights").pivot(index="month", columns="year", values="passengers")

flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %% [markdown]
# Приведенный выше набор данных *flights_df* показывает нам ежемесячную нагрузку в аэропорту с 1949 по 1960 год. Значения представляют собой количество пассажиров (в тысячах), прошедших через вход аэропорта.

# %%
sns.heatmap(flights)
plt.show()

# %% [markdown]
# Чем светлее цвет, тем выше пешеходная заходка в аэропорту. Глядя на график, мы можем сделать вывод, что:
#
# - Самые высокие значения в июле и августе.
# - Количество пешеходов растет с каждым годом.
# - Любой месяц в году будет иметь более высокую проходимость по сравнению с предыдущими годами.

# %%
sns.heatmap(flights, fmt = 'd', annot = True, cmap = 'Blues')
plt.show()

# %% [markdown]
# ## Анализ данных на примере датасета Titanic

# %%
# Настройки визуализации
sns.set_style(style='white')
sns.set(rc={
    'figure.figsize':(12,7),
    'axes.facecolor': 'white',
    'axes.grid': True, 'grid.color': '.9',
    'axes.linewidth': 1.0,
    'grid.linestyle': u'-'},font_scale=1.5)
custom_colors = ["#3498db", "#95a5a6","#34495e", "#2ecc71", "#e74c3c"]
sns.set_palette(custom_colors)

# %% [markdown]
# Загрузим данные и посмотрим информацию о них.

# %%
import pandas as pd
df = pd.read_csv("../DBs/titanic.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %% [markdown]
# ### Анализируем класс (Pclass)

# %% [markdown]
# Посмотрим, какие классы есть в данных.

# %%
df.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %% [markdown]
# Команда **value_counts()** позволяется вывести количество для каждого уникального значения. Запомним ее.

# %%
df.Pclass.value_counts()
# Out:
# Pclass
# 3    487
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.Pclass.value_counts().plot.pie().legend(labels=["Class 3","Class 1","Class 2"], loc='center right', bbox_to_anchor=(2.25, 0.5)).set_title("Распределение пассажиров по классам")

# %%
pclass_1_survivor_distribution = round((df[df.Pclass == 1].Survived == 1).value_counts()[1]/len(df[df.Pclass == 1]) * 100, 2)
pclass_2_survivor_distribution = round((df[df.Pclass == 2].Survived == 1).value_counts()[1]/len(df[df.Pclass == 2]) * 100, 2)
pclass_3_survivor_distribution = round((df[df.Pclass == 3].Survived == 1).value_counts()[1]/len(df[df.Pclass == 3]) * 100, 2)
pclass_perc_df = pd.DataFrame(
    { "Выжили":{"Class 1": pclass_1_survivor_distribution,"Class 2": pclass_2_survivor_distribution, "Class 3": pclass_3_survivor_distribution},
     "Погибли":{"Class 1": 100-pclass_1_survivor_distribution,"Class 2": 100-pclass_2_survivor_distribution, "Class 3": 100-pclass_3_survivor_distribution}})
pclass_perc_df.plot.bar().set_title("Процент выживших по классам")
plt.show()
# Out:
# C:\Users\MrDarked\AppData\Local\Temp\ipykernel_11212\3084343075.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pclass_1_survivor_distribution = round((df[df.Pclass == 1].Survived == 1).value_counts()[1]/len(df[df.Pclass == 1]) * 100, 2)
# C:\Users\MrDarked\AppData\Local\Temp\ipykernel_11212\3084343075.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pclass_2_survivor_distribution = round((df[df.Pclass == 2].Survived == 1).value_counts()[1]/len(df[df.Pclass == 2]) * 100, 2)
# C:\Users\MrDarked\AppData\Local\Temp\ipykernel_11212\3084343075.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pclass_3_survivor_distribution = round((df[df.Pclass == 3].Survived == 1).value_counts()[1]/len(df[df.Pclass == 3]) * 100, 2)

# %% [markdown]
# *Пример анализа по показателю:*
#
# Показатель **Pclass** - класс, соотвествующий билету пассажира. Пассажиры могли выбрать из трех отдельных классов, а именно: класс 1, класс 2 и класс 3. Третий класс имел наибольшее количество пассажиров, затем класс 2 и класс 1. Количество пассажиров в третьем классе было больше, чем количество пассажиров в первом и втором классе вместе взятых. Вероятность выживания пассажира класса 1 была выше, чем пассажира класса 2 и класса 3.

# %% [markdown]
# ### Анализ показателя пол (Sex)

# %%
df.Sex.value_counts(normalize = True)
# Out:
# Sex
# male      0.645998
# female    0.354002
# Name: proportion, dtype: float64

# %% [markdown]
# Построим **barplot** процент женщин и мужчин на Титанике.

# %%
(df.Sex.value_counts(normalize = True) * 100).plot.bar()
plt.show()

# %% [markdown]
# Посмотрим процент выживших среди мужчин и женщин.

# %%
df[df.Sex == 'male'].Survived == 1
# Out:
# 0      False
# 4      False
# 5      False
# 6      False
# 7      False
#        ...
# 879    False
# 880    False
# 882    False
# 885     True
# 886    False
# Name: Survived, Length: 573, dtype: bool

# %%
(df[df.Sex == 'male'].Survived == 1).value_counts()
# Out:
# Survived
# False    464
# True     109
# Name: count, dtype: int64

# %%
round((df[df.Sex == 'male'].Survived == 1).value_counts()[1]/len(df.Sex)*100,2)
# Out:
# C:\Users\MrDarked\AppData\Local\Temp\ipykernel_11212\1894508938.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   round((df[df.Sex == 'male'].Survived == 1).value_counts()[1]/len(df.Sex)*100,2)
# 12.29

# %%
male_pr = round((df[df.Sex == 'male'].Survived == 1).value_counts()[1]/len(df.Sex) * 100, 2)
female_pr = round((df[df.Sex == 'female'].Survived == 1).value_counts()[1]/len(df.Sex) * 100, 2)
sex_perc_df = pd.DataFrame(
    { "Процент выживших":{"мужчины": male_pr,"женщины": female_pr},  "Погибшие":{"мужчины": 100-male_pr,"женщины": 100-female_pr}})
sex_perc_df.plot.barh().set_title("Процент выживших в разрезе м/ж")
plt.show()
# Out:
# C:\Users\MrDarked\AppData\Local\Temp\ipykernel_11212\3979448701.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   male_pr = round((df[df.Sex == 'male'].Survived == 1).value_counts()[1]/len(df.Sex) * 100, 2)
# C:\Users\MrDarked\AppData\Local\Temp\ipykernel_11212\3979448701.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   female_pr = round((df[df.Sex == 'female'].Survived == 1).value_counts()[1]/len(df.Sex) * 100, 2)

# %% [markdown]
# *Пример анализа:*
#
# Примерно 65% пассажиров составляли мужчины, а остальные 35% — женщины. Тем не менее, процент выживших женщин был выше, чем число выживших мужчин. Более 80% мужчин умерли, в сравнении с примерно 70% женщинами.

# %% [markdown]
# ### Анализируем возраст (Age)

# %%
min(df['Age'])
# Out:
# 0.42

# %%
max(df['Age'])
# Out:
# 80.0

# %% [markdown]
# Зададим интервалы и сгруппируем данные в эти интервалы.

# %%
df['Age_Range'] = pd.cut(df.Age, [0, 10, 20, 30, 40, 50, 60,70,80])
sns.countplot(x = "Age_Range", hue = "Survived", data = df, palette=["C1", "C0"]).legend(labels = ["Погибли", "Выжили"])
plt.show()
# Out:
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# e:\Python\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Server\MLabs-IIS-lessons_python\Task3\3_visualize_data.ipynb Ячейка 72 line 2
#       <a href='vscode-notebook-cell:/c%3A/Server/MLabs-IIS-lessons_python/Task3/3_visualize_data.ipynb#Y131sZmlsZQ%3D%3D?line=0'>1</a> df['Age_Range'] = pd.cut(df.Age, [0, 10, 20, 30, 40, 50, 60,70,80])
# ----> <a href='vscode-notebook-cell:/c%3A/Server/MLabs-IIS-lessons_python/Task3/3_visualize_data.ipynb#Y131sZmlsZQ%3D%3D?line=1'>2</a> sns.countplot(x = "Age_Range", hue = "Survived", data = df, palette=["C1", "C0"]).legend(labels = ["Погибли", "Выжили"])
#       <a href='vscode-notebook-cell:/c%3A/Server/MLabs-IIS-lessons_python/Task3/3_visualize_data.ipynb#Y131sZmlsZQ%3D%3D?line=2'>3</a> plt.show()
#
# File e:\Python\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File e:\Python\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File e:\Python\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
#     766 if self.hue_names is not None:
# --> 767     ax.legend(loc="best", title=self.hue_title)
#
# File e:\Python\Lib\site-packages\matplotlib\axes\_axes.py:322, in Axes.legend(self, *args, **kwargs)
#     204 @_docstring.dedent_interpd
#     205 def legend(self, *args, **kwargs):
#     206     """
#     207     Place a legend on the Axes.
#     208
#    (...)
#     320     .. plot:: gallery/text_labels_and_annotations/legend.py
#     321     """
# --> 322     handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
#     323     self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     324     self.legend_._remove_method = self._remove_legend
#
# File e:\Python\Lib\site-packages\matplotlib\legend.py:1361, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1357     handles = [handle for handle, label
#    1358                in zip(_get_legend_handles(axs, handlers), labels)]
#    1360 elif len(args) == 0:  # 0 args: automatically detect labels and handles.
# -> 1361     handles, labels = _get_legend_handles_labels(axs, handlers)
#    1362     if not handles:
#    1363         log.warning(
#    1364             "No artists with labels found to put in legend.  Note that "
#    1365             "artists whose label start with an underscore are ignored "
#    1366             "when legend() is called with no argument.")
#
# File e:\Python\Lib\site-packages\matplotlib\legend.py:1291, in _get_legend_handles_labels(axs, legend_handler_map)
#    1289 for handle in _get_legend_handles(axs, legend_handler_map):
#    1290     label = handle.get_label()
# -> 1291     if label and not label.startswith('_'):
#    1292         handles.append(handle)
#    1293         labels.append(label)
#
# AttributeError: 'numpy.int64' object has no attribute 'startswith'

# %%
sns.distplot(df['Age'].dropna(),color='darkgreen',bins=30)
plt.show()
# Out:
# C:\Users\MrDarked\AppData\Local\Temp\ipykernel_11212\2470891357.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'].dropna(),color='darkgreen',bins=30)
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Самому молодому путешественнику на борту было около двух месяцев, а самому старшему — 80 лет. Средний возраст пассажиров на борту был чуть менее 30 лет. Большая часть детей в возрасте до 10 лет выжила. В любой другой возрастной группе число жертв было выше, чем число выживших. Более 140 человек в возрастной группе 20-30 лет погибли в сравнении с примерно 80 выжившими того же возраста.

# %% [markdown]
# ### Самостоятельно анализируем стоимость тарифа (Fare) (5 баллов)

# %% [markdown]
# Схема анализа:
#
# 1) посмотреть с помощью value_counts() какие есть тарифы
#
# 2) возможно объединить тарифы в категории (например, Дешевые, Средние, Выше Среднего, Высокие) и создать новую переменную. Подсказка для разделения функция describe
#
# 3) визуализировать график и ответить на вопрос: "Как стоимость тарифа влияет на вероятность выживания?"

# %%
# решение
df['Fare'].describe()
# Out:
# count    887.00000
# mean      32.30542
# std       49.78204
# min        0.00000
# 25%        7.92500
# 50%       14.45420
# 75%       31.13750
# max      512.32920
# Name: Fare, dtype: float64

# %%
def categorize_fare(fare):
    if fare <= df['Fare'].describe()['25%']:
        return 'Дешевые'
    elif fare <= df['Fare'].describe()['50%']:
        return 'Средние'
    elif fare <= df['Fare'].describe()['75%']:
        return 'Выше Среднего'
    else:
        return 'Высокие'

df['Fare_Category'] = df['Fare'].apply(categorize_fare)
print(df['Fare_Category'].value_counts())
# Out:
# Fare_Category
# Дешевые          238
# Высокие          222
# Выше Среднего    221
# Средние          206
# Name: count, dtype: int64

# %%
sns.barplot(x='Fare_Category', y='Survived', data=df, order=['Дешевые', 'Средние', 'Выше Среднего', 'Высокие'], errorbar=None)

plt.xlabel('Категория тарифа')
plt.ylabel('Вероятность выживания')

plt.title('Влияние стоимости тарифа на вероятность выживания')

plt.show()
# Out:
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ### Самостоятельно анализируем Siblings/Spouses Aboard и Parents/Children Aboard (10 баллов)
#
# SibSp — это число братьев, сестер или супругов на борту у человека.
#
# Parents/Children Aboard - признак содержал количество родителей или детей, с которыми путешествовал каждый пассажир.

# %% [markdown]
# Вопросы для анализа:
# 1. Как влияет наличие семьи на выживаемость?
# 2. Какие путешествия чаще: в одиночку или с родственниками?
# 3. Насколько изменяются шансы на выживание в случае путешествия в одиночку?

# %%
# для удобства переименуем колонки
df.columns = ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'ParCh', 'Fare', 'Age_Range', 'Fare_Category']
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  SibSp  ParCh     Fare Age_Range  Fare_Category
# 0      male  22.0      1      0   7.2500  (20, 30]        Дешевые
# 1    female  38.0      1      0  71.2833  (30, 40]        Высокие
# 2    female  26.0      0      0   7.9250  (20, 30]        Дешевые
# 3    female  35.0      1      0  53.1000  (30, 40]        Высокие
# 4      male  35.0      0      0   8.0500  (30, 40]        Средние
# ..      ...   ...    ...    ...      ...       ...            ...
# 882    male  27.0      0      0  13.0000  (20, 30]        Средние
# 883  female  19.0      0      0  30.0000  (10, 20]  Выше Среднего
# 884  female   7.0      1      2  23.4500   (0, 10]  Выше Среднего
# 885    male  26.0      0      0  30.0000  (20, 30]  Выше Среднего
# 886    male  32.0      0      0   7.7500  (30, 40]        Дешевые
#
# [887 rows x 10 columns]

# %%
df['Family'] = df['SibSp'] + df['ParCh']
df['Family']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 882    0
# 883    0
# 884    3
# 885    0
# 886    0
# Name: Family, Length: 887, dtype: int64

# %%
# решение


sns.barplot(x='Family', y='Survived', data=df, errorbar=None)

plt.xlabel('Кол-во родственников')
plt.ylabel('Вероятность выживания')

plt.title('Влияние кол-ва родственников на вероятность выживания')

plt.show()
# Out:
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Вывод: наибольшую выживаемость имели пары и небольшие семьи, а многодетные семьи и одинокие люди чаще погибали

# %%
df['Is_Alone'] = df.Family == 0
df.groupby('Is_Alone')['Survived'].mean()
# Out:
# Is_Alone
# False    0.505650
# True     0.305816
# Name: Survived, dtype: float64

# %%
plt.pie(df['Is_Alone'].value_counts(), labels=['Одинокие', 'С родственниками'], autopct='%1.1f%%', colors=['#66b3ff', '#ff9999'], startangle=90)
plt.title('Соотношение одиноких пассажиров и пассажиров с родственниками')
plt.axis('equal')

plt.show()

# %%
# решение


sns.barplot(x='Is_Alone', y='Survived', estimator='mean', data=df, errorbar=None)

plt.xlabel('Наличие родственников')
plt.ylabel('Вероятность выживания')

plt.title('Влияние родственников на вероятность выживания')
plt.xticks([0, 1], labels=['С родственниками', 'Одинокие'])

plt.show()
# Out:
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Вывод: одинокие люди реже выживали

# %%
pivot_table = df.pivot_table(index='Family', values='Age', aggfunc='mean')

plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, cmap='YlGnBu')
plt.xlabel('Количество родственников')
plt.ylabel('Средний возраст')
plt.title('Средний возраст пассажиров по количеству родственников')

plt.show()

# %%
sns.kdeplot(data=df, x='Age', hue='Survived', fill=True)
plt.title('Сравнение распределения возраста с учетом выживаемости')
plt.xlabel('Возраст')
plt.ylabel('Плотность')

plt.show()
# Out:
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\Python\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
